# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
###sasac
# Suppress warnings for cleaner output
warnings.filterwarnings('ignore')

# Load the processed dataset
CSV_PATH = 'data/processed_products_with_images.csv'
df = pd.read_csv(CSV_PATH)

# Display basic information about the dataset
print("Dataset Info:")
print(df.info())

# Display first few rows
print("\nFirst few rows of the dataset:")
print(df.head())

# Basic statistics
print("\nBasic statistics:")
print(df.describe())

# Check for missing values
print("\nMissing values per column:")
print(df.isnull().sum())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51297 entries, 0 to 51296
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   sku            51297 non-null  int64
#  1   name           51297 non-null  object
#  2   description    51297 non-null  object
#  3   image          51297 non-null  object
#  4   type           51297 non-null  object
#  5   price          51297 non-null  float64
#  6   shipping       48264 non-null  float64
#  7   manufacturer   51290 non-null  object
#  8   class_id       51297 non-null  object
#  9   sub_class1_id  50744 non-null  object
#  10  num_classes    51297 non-null  int64
#  11  image_path     49689 non-null  object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 4.7+ MB
# None
#
# First few rows of the dataset:
#       sku                                             name  \
# 0   43900                Duracell - AAA Batteries (4-Pack)
# ...

# %%
# downloading 
import pandas as pd
import numpy as np
from PIL import Image
from io import BytesIO
import requests
import os
from src.utils import ImageDownloader  # Import the ImageDownloader class

# Load the data:
CSV_PATH = 'data/processed_products_with_images.csv'  # Changed to the correct file
df = pd.read_csv(CSV_PATH)

# Download the images and add the image paths to the dataframe:
DIR = 'data/images/'
SHAPE = (224, 224)
OVERWRITE = False
OUTPUT_CSV = 'data/processed_products_with_images.csv'  # This will overwrite the existing file

# Instantiate the ImageDownloader class
image_downloader = ImageDownloader(image_dir=DIR, image_size=SHAPE, overwrite=OVERWRITE)

# Download images and get the updated DataFrame
updated_df = image_downloader.download_images(df)

# Save the updated DataFrame
updated_df.to_csv(OUTPUT_CSV, index=False)
# Out:
# ...
# Could not download image for SKU: 1003163. Error: 404 Client Error: Not Found for url: http://img.bbystatic.com/BestBuy_US/images/pac/products/1312/1312451498/1312451498_sa.jpg
# Could not download image for SKU: 1005903. Error: 404 Client Error: Not Found for url: http://img.bbystatic.com/BestBuy_US/images/pac/products/1306/1306786803/1306786803_sa.jpg
# Could not download image for SKU: 1057082. Error: 404 Client Error: Not Found for url: http://img.bbystatic.com/BestBuy_US/images/pac/products/1312/1312657746/1312657746_sa.jpg
# Could not download image for SKU: 1057188. Error: 404 Client Error: Not Found for url: http://img.bbystatic.com/BestBuy_US/images/pac/products/1312/1312657739/1312657739_sa.jpg
# Could not download image for SKU: 1098873. Error: 404 Client Error: Not Found for url: http://img.bbystatic.com/BestBuy_US/images/pac/products/1312/1312400892/1312400892_sa.jpg
# ...
